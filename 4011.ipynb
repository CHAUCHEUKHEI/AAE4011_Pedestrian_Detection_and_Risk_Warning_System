# %% [markdown]
# <a href="https://colab.research.google.com/github/CHAUCHEUKHEI/AAE4011_Pedestrian_Detection_and_Risk_Warning_System/blob/main/4011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/pedestrian-detection/4011')
# !ls   # confirms your files are visible
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9721/1522397607.py in <cell line: 0>()
#       1 import os
# ----> 2 os.chdir('/content/drive/MyDrive/pedestrian-detection/4011')
#       3 get_ipython().system('ls   # confirms your files are visible')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/pedestrian-detection/4011'

# %%
import torch
print(torch.cuda.is_available())

# %%
# !pip install -r requirements.txt
# !pip install ultralytics
# !pip install beepy
# !python main_4011.py
